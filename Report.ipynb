# %%
from Bandit import EpsilonGreedy, ThompsonSampling, Visualization, comparison

# %%
epsilon_greedy = EpsilonGreedy(5)
thompson = ThompsonSampling(5)

# %%
result_epsilon_greedy = epsilon_greedy.experiment(20000)
result_thompson = thompson.experiment(20000)

# %%
vis = Visualization()
vis.plot1(result_epsilon_greedy)
# Out:
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]

# %%
vis.plot1(result_thompson)
# Out:
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]

# %%
thompson.report(result_thompson)
# Out:
# Thompson Sampling Performance
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# average reward is 4.864013795160889
# average regret is -0.0009609944642016386
# ...

# %%
epsilon_greedy.report(result_epsilon_greedy)
# Out:
# Epsilon Greedy Performance
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# D:\Annie\AUA ugrad\Semester_7_(Fall_2023)\Marketing Analytics\HW_2\Bandit.py:96: RuntimeWarning: divide by zero encountered in log
#   cum_sum = np.log(cumulative_sum)[:, bandit]
# average reward is 1.0007765352899711
# average regret is -1.0007765352899711
# ...
